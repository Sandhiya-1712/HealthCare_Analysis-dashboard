# %%
import pandas as pd
from sqlalchemy import create_engine

username = "root"
password = "Sandhi%401999"
host = "localhost"
database = "healthcare_dashboard"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}/{database}"
)

print("Connected")

# Upload Cleaned_payers

Cleaned_payers = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_payers.csv")

Cleaned_payers.to_sql(
    name="cleaned_payers",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_payers uploaded successfully!")

# %%
Cleaned_Patients = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_Patients.csv")

Cleaned_Patients.to_sql(
    name="cleaned_patients",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_Patients uploaded successfully!")

# %%
Cleaned_Procedures = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_Procedures.csv")

Cleaned_Procedures.to_sql(
    name="cleaned_procedures",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_Procedures uploaded successfully!")
# Out:
# Connected
# Cleaned_Procedures uploaded successfully!

# %%
Cleaned_Providers = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_Providers.csv")

Cleaned_Providers.to_sql(
    name="cleaned_providers",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_Providers uploaded successfully!")

# %%
Cleaned_Organizations = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_Organizations.csv")

Cleaned_Organizations.to_sql(
    name="cleaned_organizations",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_Organizations uploaded successfully!")

# %%
Cleaned_Observations = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_Observations.csv")

Cleaned_Observations.to_sql(
    name="cleaned_observations",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_Observations uploaded successfully!")

# %%
Cleaned_Medications = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_Medications.csv")

Cleaned_Medications.to_sql(
    name="cleaned_medications",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_Medications uploaded successfully!")

# %%
Cleaned_Encounters = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_Encounters.csv")

Cleaned_Encounters.to_sql(
    name="cleaned_encounters",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_Encounters uploaded successfully!")

# %%
Cleaned_Conditions = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_Conditions.csv")

Cleaned_Conditions.to_sql(
    name="cleaned_conditions",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_Conditions uploaded successfully!")

# %%
Cleaned_Careplans = pd.read_csv("C:/Users/ssand/OneDrive/Documents/A - Synthea/HealthCare_Analysis dashboard/02_CLEANED_DATASET/Cleaned_Careplans.csv")

Cleaned_Careplans.to_sql(
    name="cleaned_careplans",
    con=engine,
    if_exists="replace",
    index=False
)

print("Cleaned_Careplans uploaded successfully!")
